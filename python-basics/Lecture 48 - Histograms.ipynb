# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  6.,  10.,  18.,  13.,  20.,  13.,  11.,   4.,   4.,   1.]),
#  array([-2.13597809, -1.65785391, -1.17972973, -0.70160555, -0.22348137,
#          0.25464281,  0.73276699,  1.21089117,  1.68901535,  2.16713954,
#          2.64526372]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color='indianred')
# Out:
# (array([  1.,   3.,   4.,  13.,  13.,  14.,  18.,   7.,   6.,   1.]),
#  array([-2.49545426, -2.02638371, -1.55731317, -1.08824262, -0.61917208,
#         -0.15010153,  0.31896901,  0.78803956,  1.2571101 ,  1.72618065,
#          2.19525119]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, color='indianred', alpha=0.5,
        bins=20)
plt.hist(dataset2, normed=True, alpha=0.5,
        bins=20)
# Out:
# (array([ 0.05329689,  0.        ,  0.10659377,  0.05329689,  0.21318755,
#          0.        ,  0.21318755,  0.47967199,  0.26648444,  0.4263751 ,
#          0.37307821,  0.37307821,  0.63956265,  0.31978132,  0.10659377,
#          0.26648444,  0.21318755,  0.10659377,  0.        ,  0.05329689]),
#  array([-2.49545426, -2.26091898, -2.02638371, -1.79184844, -1.55731317,
#         -1.32277789, -1.08824262, -0.85370735, -0.61917208, -0.3846368 ,
#         -0.15010153,  0.08443374,  0.31896901,  0.55350429,  0.78803956,
#          1.02257483,  1.2571101 ,  1.49164538,  1.72618065,  1.96071592,
#          2.19525119]),
#  <a list of 20 Patch objects>)

# %%
d1 = randn(1000)
d2 = randn(1000)

# %%
sns.jointplot(d1, d2)

# %%
sns.jointplot(d1, d2, kind='hex')
