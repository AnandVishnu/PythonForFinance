# %%
import numpy as np
import pandas as pd
from pandas import Series as s, DataFrame as df

# %%
df1 = pd.read_csv('data/bikes.csv')

# %%
df1
# Out:
#            Date Unnamed: 1  Berri1  Boyer  Br̩beuf  \
# 0    01/01/2016      00:00      32      0        27
# 1    02/01/2016      00:00      68      0         6
# 2    03/01/2016      00:00      78      3         4
# 3    04/01/2016      00:00     118      6        60
# 4    05/01/2016      00:00     183      2        25
# 5    06/01/2016      00:00     305      3        14
# 6    07/01/2016      00:00     425      0        10
# 7    08/01/2016      00:00     393      1        14
# 8    09/01/2016      00:00     139      7         4
# 9    10/01/2016      00:00     136     30        11
# 10   11/01/2016      00:00     393     31        28
# 11   12/01/2016      00:00     398     12        21
# 12   13/01/2016      00:00     324      0        15
# 13   14/01/2016      00:00     347      1         2
# 14   15/01/2016      00:00     367      0         1
# 15   16/01/2016      00:00     113      0         5
# 16   17/01/2016      00:00     111      0         8
# ...

# %%
df2 = pd.read_csv('data/bikes.csv', header=None)
df2.head()
# Out:
#            0      1       2      3         4                             5   \
# 0        Date    NaN  Berri1  Boyer  Br̩beuf  CSC (C̫te Sainte-Catherine)
# 1  01/01/2016  00:00      32      0        27                             0
# 2  02/01/2016  00:00      68      0         6                             0
# 3  03/01/2016  00:00      78      3         4                             0
# 4  04/01/2016  00:00     118      6        60                             2
#
#               6              7           8     9        10  \
# 0  Maisonneuve_2  Maisonneuve_3  Notre-Dame  Parc  PierDup
# 1             51             16           1     5        1
# 2             93             25           2    16        6
# 3            118             38           0     6        1
# 4            165             80           0    46        0
#
#                      11                        12                 13  \
# 0  Pont_Jacques_Cartier  Rachel / H̫tel de Ville  Rachel / Papineau
# ...

# %%
df3 = pd.read_table('data/bikes.csv', sep=',', header=None)

# %%
df3
# Out:
#              0      1       2      3         4                             5   \
# 0          Date    NaN  Berri1  Boyer  Br̩beuf  CSC (C̫te Sainte-Catherine)
# 1    01/01/2016  00:00      32      0        27                             0
# 2    02/01/2016  00:00      68      0         6                             0
# 3    03/01/2016  00:00      78      3         4                             0
# 4    04/01/2016  00:00     118      6        60                             2
# 5    05/01/2016  00:00     183      2        25                             2
# 6    06/01/2016  00:00     305      3        14                            45
# 7    07/01/2016  00:00     425      0        10                            70
# 8    08/01/2016  00:00     393      1        14                            77
# 9    09/01/2016  00:00     139      7         4                            34
# 10   10/01/2016  00:00     136     30        11                            59
# ...

# %%
df4 = pd.read_csv('data/bikes.csv', nrows=5)
df4
# Out:
#          Date Unnamed: 1  Berri1  Boyer  Br̩beuf  \
# 0  01/01/2016      00:00      32      0        27
# 1  02/01/2016      00:00      68      0         6
# 2  03/01/2016      00:00      78      3         4
# 3  04/01/2016      00:00     118      6        60
# 4  05/01/2016      00:00     183      2        25
#
#    CSC (C̫te Sainte-Catherine)  Maisonneuve_2  Maisonneuve_3  Notre-Dame  \
# 0                             0             51             16           1
# 1                             0             93             25           2
# 2                             0            118             38           0
# 3                             2            165             80           0
# 4                             2            239             86           2
#
#    Parc  PierDup  Pont_Jacques_Cartier  Rachel / H̫tel de Ville  \
# 0     5        1                    13                       NaN
# 1    16        6                     9                       NaN
# ...

# %%
import sys

# %%
df4.to_csv(sys.stdout)
# Out:
# ,Date,Unnamed: 1,Berri1,Boyer,Br̩beuf,CSC (C̫te Sainte-Catherine),Maisonneuve_2,Maisonneuve_3,Notre-Dame,Parc,PierDup,Pont_Jacques_Cartier,Rachel / H̫tel de Ville,Rachel / Papineau,Ren̩-L̩vesque,Saint-Antoine,Saint-Urbain,Totem_Laurier,University,Viger
# 0,01/01/2016,00:00,32,0,27,0,51,16,1,5,1,13,,93,12,6,38,68,14,11
# 1,02/01/2016,00:00,68,0,6,0,93,25,2,16,6,9,,141,16,11,67,106,30,14
# 2,03/01/2016,00:00,78,3,4,0,118,38,0,6,1,6,,116,25,10,21,59,25,5
# 3,04/01/2016,00:00,118,6,60,2,165,80,0,46,0,3,,202,49,9,4,99,111,29
# 4,05/01/2016,00:00,183,2,25,2,239,86,2,110,5,3,,241,77,12,11,106,158,44

# %%
df4.to_csv(sys.stdout, sep='#')
# Out:
# #Date#Unnamed: 1#Berri1#Boyer#Br̩beuf#CSC (C̫te Sainte-Catherine)#Maisonneuve_2#Maisonneuve_3#Notre-Dame#Parc#PierDup#Pont_Jacques_Cartier#Rachel / H̫tel de Ville#Rachel / Papineau#Ren̩-L̩vesque#Saint-Antoine#Saint-Urbain#Totem_Laurier#University#Viger
# 0#01/01/2016#00:00#32#0#27#0#51#16#1#5#1#13##93#12#6#38#68#14#11
# 1#02/01/2016#00:00#68#0#6#0#93#25#2#16#6#9##141#16#11#67#106#30#14
# 2#03/01/2016#00:00#78#3#4#0#118#38#0#6#1#6##116#25#10#21#59#25#5
# 3#04/01/2016#00:00#118#6#60#2#165#80#0#46#0#3##202#49#9#4#99#111#29
# 4#05/01/2016#00:00#183#2#25#2#239#86#2#110#5#3##241#77#12#11#106#158#44

# %%
df4.to_csv(sys.stdout, sep='#', columns=['Date', 'Berry1'])
# Out:
# #Date#Berry1
# 0#01/01/2016#
# 1#02/01/2016#
# 2#03/01/2016#
# 3#04/01/2016#
# 4#05/01/2016#
